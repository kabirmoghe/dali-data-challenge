# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

# %%
store = pd.read_csv("Sample - Superstore.csv", index_col = 0)

# %%
courses = pd.read_csv("Dartmouth - Courses.csv", index_col = 0)

# %%
store
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1.0  CA-2016-152156   11/8/2016  11/11/2016             NaN
# 1        NaN             NaN   11/8/2016  11/11/2016    Second Class
# 2        3.0             NaN   6/12/2016   6/16/2016    Second Class
# 3        4.0  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5.0  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989  9990.0             NaN   1/21/2014   1/23/2014    Second Class
# 9990  9991.0  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991  9992.0  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992     NaN  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993  9994.0  CA-2017-119914    5/4/2017    5/9/2017             NaN
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
courses['Department'].unique()
# Out:
# array(['AAAS', 'ANTH', nan, 'ARTH', 'ASCL', 'ASTR', 'BIOL', 'CHEM',
#        'CLST', 'COGS', 'COLT', 'COSC', 'CRWT', 'EARS', 'ECON', 'EDUC',
#        'ENGL', 'ENGS', 'ENVS', 'FILM', 'FREN', 'FRIT', 'GEOG', 'GERM',
#        'GOVT', 'HIST', 'HUM', 'JWST', 'LACS', 'LAT', 'LATS', 'LING',
#        'MATH', 'MES', 'MUS', 'NAS', 'PBPL', 'PHIL', 'PHYS', 'PORT',
#        'PSYC', 'REL', 'RUSS', 'SART', 'SOCY', 'SPAN', 'THEA', 'WGSS',
#        'CHIN', 'COCO', 'INTS', 'ITAL', 'QSS', 'SPEE', 'TUCK', 'WRIT',
#        'JAPN', 'MALS', 'GRK'], dtype=object)

# %%
courses['Course Number'].nunique()
# Out:
# 557

# %%
dept_metrics = courses.groupby('Department')[['Enrollments','Median GPA Points','Average Section Size']].mean()

# %%
dept_metrics['Enrollments'] = dept_metrics['Enrollments'].round()
dept_metrics['Median GPA Points'] = dept_metrics['Median GPA Points'].round(2)
dept_metrics['Average Section Size'] = dept_metrics['Average Section Size'].round()

# %%
sns.scatterplot(data=courses,x="Average Section Size",y="Enrollments")
# Out:
# <Axes: xlabel='Average Section Size', ylabel='Enrollments'>

# %%
courses
# Out:
#         Year  Term Number Department  Course Number  Number of Sections  \
# 0        NaN          NaN       AAAS          31.10                 1.0
# 1     2021.0          3.0       AAAS          31.90                 1.0
# 2     2021.0          3.0       AAAS          60.01                 1.0
# 3     2021.0          3.0       AAAS          62.75                 1.0
# 4     2021.0          3.0       AAAS          65.65                 1.0
# ...      ...          ...        ...            ...                 ...
# 1555  2022.0          2.0       WRIT           7.34                 1.0
# 1556  2022.0          2.0       WRIT           7.35                 1.0
# 1557     NaN          2.0       WRIT           7.36                 1.0
# 1558  2022.0          2.0       WRIT           7.37                 2.0
# 1559  2022.0          2.0       WRIT           7.38                 1.0
#
#       Enrollments  Median GPA Points  Average Section Size
# ...

# %%
* Can I use the GPA +
